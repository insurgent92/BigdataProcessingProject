# %% [markdown]
# ## 1. Import pakages

# %%
import keras
from keras.callbacks import ModelCheckpoint
from keras import models
from keras import layers
import time
keras.__version__
# Out:
# '2.1.6'

# %% [markdown]
# ## 2. Import MNIST

# %%
from keras.datasets import mnist
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# ## 3. Import Models

# %%
from keras.models import load_model
network1 = load_model('./models/mnist_depth_1(no_trained).h5')
network2 = load_model('./models/mnist_depth_2(no_trained).h5')
network3 = load_model('./models/mnist_depth_3(no_trained).h5')
network4 = load_model('./models/mnist_depth_4(no_trained).h5')
network5 = load_model('./models/mnist_depth_5(no_trained).h5')

# %% [markdown]
# ## 4. Fit

# %%
start_time = time.time() 
result1 = network1.fit(train_images, train_labels, epochs= 10, batch_size=128, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))

start_time = time.time() 
result2 = network2.fit(train_images, train_labels, epochs= 10, batch_size=128, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))

start_time = time.time() 
result3 = network3.fit(train_images, train_labels, epochs= 10, batch_size=128, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))

start_time = time.time() 
result4 = network4.fit(train_images, train_labels, epochs= 10, batch_size=128, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))

start_time = time.time() 
result5 = network5.fit(train_images, train_labels, epochs= 10, batch_size=128, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 1s 17us/step - loss: 0.2640 - acc: 0.9331 - val_loss: 0.2364 - val_acc: 0.9403
# Epoch 2/10
# 54000/54000 [==============================] - 1s 18us/step - loss: 0.2633 - acc: 0.9331 - val_loss: 0.2355 - val_acc: 0.9390
# Epoch 3/10
# 54000/54000 [==============================] - 1s 16us/step - loss: 0.2621 - acc: 0.9333 - val_loss: 0.2351 - val_acc: 0.9395
# Epoch 4/10
# 54000/54000 [==============================] - 1s 17us/step - loss: 0.2618 - acc: 0.9330 - val_loss: 0.2358 - val_acc: 0.9398
# Epoch 5/10
# 54000/54000 [==============================] - 1s 17us/step - loss: 0.2609 - acc: 0.9331 - val_loss: 0.2351 - val_acc: 0.9392
# Epoch 6/10
# 54000/54000 [==============================] - 1s 17us/step - loss: 0.2604 - acc: 0.9334 - val_loss: 0.2351 - val_acc: 0.9402
# Epoch 7/10
# 54000/54000 [==============================] - 1s 17us/step - loss: 0.2598 - acc: 0.9337 - val_loss: 0.2345 - val_acc: 0.9417
# Epoch 8/10
# 54000/54000 [==============================] - 1s 18us/step - loss: 0.2593 - acc: 0.9337 - val_loss: 0.2335 - val_acc: 0.9418
# Epoch 9/10
# 54000/54000 [==============================] - 1s 17us/step - loss: 0.2589 - acc: 0.9337 - val_loss: 0.2361 - val_acc: 0.9415
# Epoch 10/10
# 54000/54000 [==============================] - 1s 17us/step - loss: 0.2581 - acc: 0.9335 - val_loss: 0.2345 - val_acc: 0.9395
# start_time 1525111678.9702652
# --- 9.175258874893188 seconds ---
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 1s 26us/step - loss: 0.0113 - acc: 0.9989 - val_loss: 0.1670 - val_acc: 0.9833
# Epoch 2/10
# 54000/54000 [==============================] - 1s 26us/step - loss: 0.0122 - acc: 0.9987 - val_loss: 0.1865 - val_acc: 0.9845
# Epoch 3/10
# 54000/54000 [==============================] - 1s 27us/step - loss: 0.0089 - acc: 0.9991 - val_loss: 0.1733 - val_acc: 0.9850
# Epoch 4/10
# 54000/54000 [==============================] - 1s 26us/step - loss: 0.0085 - acc: 0.9992 - val_loss: 0.1651 - val_acc: 0.9840
# Epoch 5/10
# 54000/54000 [==============================] - 1s 26us/step - loss: 0.0087 - acc: 0.9992 - val_loss: 0.1662 - val_acc: 0.9857
# Epoch 6/10
# 54000/54000 [==============================] - 1s 27us/step - loss: 0.0115 - acc: 0.9988 - val_loss: 0.1749 - val_acc: 0.9845
# Epoch 7/10
# 54000/54000 [==============================] - 1s 27us/step - loss: 0.0095 - acc: 0.9991 - val_loss: 0.1841 - val_acc: 0.9827
# Epoch 8/10
# 54000/54000 [==============================] - 1s 26us/step - loss: 0.0097 - acc: 0.9992 - val_loss: 0.2018 - val_acc: 0.9817
# Epoch 9/10
# 54000/54000 [==============================] - 1s 24us/step - loss: 0.0106 - acc: 0.9988 - val_loss: 0.1759 - val_acc: 0.9840
# Epoch 10/10
# 54000/54000 [==============================] - 1s 25us/step - loss: 0.0108 - acc: 0.9990 - val_loss: 0.1699 - val_acc: 0.9855
# start_time 1525111688.1455674
# --- 14.145062685012817 seconds ---
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 2
# Epoch 5/10
# 54000/54000 [==============================] - 3s 53us/step - loss: 0.1301 - acc: 0.9856 - val_loss: 0.1983 - val_acc: 0.9733
# Epoch 6/10
# 54000/54000 [==============================] - 3s 55us/step - loss: 0.1167 - acc: 0.9854 - val_loss: 0.1539 - val_acc: 0.9743
# Epoch 7/10
# 54000/54000 [==============================] - 3s 54us/step - loss: 0.1018 - acc: 0.9881 - val_loss: 0.1689 - val_acc: 0.9822
# Epoch 8/10
# 54000/54000 [==============================] - 3s 53us/step - loss: 0.1215 - acc: 0.9870 - val_loss: 0.1794 - val_acc: 0.9815
# Epoch 9/10
# 54000/54000 [==============================] - 3s 53us/step - loss: 0.1640 - acc: 0.9848 - val_loss: 0.1993 - val_acc: 0.9788
# Epoch 10/10
# 54000/54000 [==============================] - 3s 56us/step - loss: 0.1115 - acc: 0.9866 - val_loss: 0.1623 - val_acc: 0.9820
# start_time 1525111745.7951934
# --- 29.102283239364624 seconds ---

# %% [markdown]
# ## 5. Save Trained Models

# %%
network1.save('./models/mnist_depth_1.h5')
network2.save('./models/mnist_depth_2.h5')
network3.save('./models/mnist_depth_3.h5')
network4.save('./models/mnist_depth_4.h5')
network5.save('./models/mnist_depth_5.h5')

# %%
n1_test_loss, n1_test_acc = network1.evaluate(test_images, test_labels)
print('n1_test_acc:', n1_test_acc)
print('n1_test_loss:', n1_test_loss)

n2_test_loss, n2_test_acc = network2.evaluate(test_images, test_labels)
print('n2_test_acc:', n2_test_acc)
print('n2_test_loss:', n2_test_loss)

n3_test_loss, n3_test_acc = network3.evaluate(test_images, test_labels)
print('n3_test_acc:', n3_test_acc)
print('n3_test_loss:', n3_test_loss)

n4_test_loss, n4_test_acc = network4.evaluate(test_images, test_labels)
print('n4_test_acc:', n4_test_acc)
print('n4_test_loss:', n4_test_loss)

n5_test_loss, n5_test_acc = network5.evaluate(test_images, test_labels)
print('n5_test_acc:', n5_test_acc)
print('n5_test_loss:', n5_test_loss)
# Out:
# 10000/10000 [==============================] - 0s 30us/step
# n1_test_acc: 0.9284
# n1_test_loss: 0.29613611396700146
# 10000/10000 [==============================] - 0s 30us/step
# n2_test_acc: 0.9832
# n2_test_loss: 0.1788841978113015
# 10000/10000 [==============================] - 0s 35us/step
# n3_test_acc: 0.9793
# n3_test_loss: 0.22750172075425618
# 10000/10000 [==============================] - 0s 34us/step
# n4_test_acc: 0.9616
# n4_test_loss: 0.6181551969528211
# 10000/10000 [==============================] - 0s 36us/step
# n5_test_acc: 0.9781
# n5_test_loss: 0.19776297428557366

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def flotResult(data1,data2,data3,data4,data5):
    plt.figure(figsize=(5,5))
   


    plt.plot(data1,'r', label='Depth_1')
    plt.plot(data2,'g', label='Depth_3')
    plt.plot(data3,'b', label='Depth_5')
    plt.plot(data4,'c', label='Depth_7')
    plt.plot(data5,'m', label='Depth_19')
    
    plt.legend(loc='upper right')
    plt.show()

# %%
flotResult(result1.history['loss'], result2.history['loss'],result3.history['loss'],result4.history['loss'],result5.history['loss'])
flotResult(result1.history['val_loss'], result2.history['val_loss'],result3.history['val_loss'],result4.history['val_loss'],result5.history['val_loss'])
flotResult(result1.history['acc'], result2.history['acc'],result3.history['acc'],result4.history['acc'],result5.history['acc'])
flotResult(result1.history['val_acc'], result2.history['val_acc'],result3.history['val_acc'],result4.history['val_acc'],result5.history['val_acc'])
