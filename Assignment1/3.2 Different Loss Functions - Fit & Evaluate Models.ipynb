# %% [markdown]
# ## 1. Import pakages

# %%
import keras
from keras.callbacks import ModelCheckpoint
from keras import models
from keras import layers
import time
keras.__version__
# Out:
# '2.1.6'

# %% [markdown]
# ## 2. Import MNIST

# %%
from keras.datasets import mnist
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# ## 3. Import Models

# %%
from keras.models import load_model

#network1 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_1(no_trained).h5')
#network2 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_2(no_trained).h5')
#network3 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_3(no_trained).h5')
#network4 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_4(no_trained).h5')
#network5 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_5(no_trained).h5')
#network6 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_6(no_trained).h5')
#network7 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_7(no_trained).h5')
network8 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_8(no_trained).h5')
network9 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_9(no_trained).h5')
#network10 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_10(no_trained).h5')
network11 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_11(no_trained).h5')
network12 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_12(no_trained).h5')
network13 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_13(no_trained).h5')
network14 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/models/mnist_loss_14(no_trained).h5')

# %%
model_path1 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model1/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path2 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model2/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path3 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model3/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path4 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model4/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path5 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model5/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path6 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model6/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path7 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model6/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint1 = ModelCheckpoint(filepath=model_path1, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint2 = ModelCheckpoint(filepath=model_path2, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint3 = ModelCheckpoint(filepath=model_path3, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint4 = ModelCheckpoint(filepath=model_path4, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint5 = ModelCheckpoint(filepath=model_path5, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint6 = ModelCheckpoint(filepath=model_path6, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint7 = ModelCheckpoint(filepath=model_path6, monitor='val_loss', verbose=1, save_best_only=True)

# %%
model_path8 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model8/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path9 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model9/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path10 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model10/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path11 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model11/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path12 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model12/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path13 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model13/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'
model_path14 = 'drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model14/' + 'loss{epoch:02d}-{val_loss:.4f}.hdf5'

cb_checkpoint8 = ModelCheckpoint(filepath=model_path8, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint9 = ModelCheckpoint(filepath=model_path9, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint10 = ModelCheckpoint(filepath=model_path10, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint11 = ModelCheckpoint(filepath=model_path11, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint12 = ModelCheckpoint(filepath=model_path12, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint13 = ModelCheckpoint(filepath=model_path13, monitor='val_loss', verbose=1, save_best_only=True)
cb_checkpoint14 = ModelCheckpoint(filepath=model_path14, monitor='val_loss', verbose=1, save_best_only=True)

# %% [markdown]
# ## 4. Fit

# %%
start_time = time.time() 
result1 = network1.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint1])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
start_time = time.time() 
result2 = network2.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint2])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
start_time = time.time() 
result3 = network3.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint3])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
start_time = time.time() 
result4 = network4.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint4])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
start_time = time.time() 
result5 = network5.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint5])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
result6 = network6.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint6])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
result7 = network7.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint7])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 2s 31us/step - loss: 0.0219 - acc: 0.8418 - val_loss: 0.0054 - val_acc: 0.9658
#
# Epoch 00001: val_loss improved from inf to 0.00539, saving model to drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model1/loss01-0.0054.hdf5
# Epoch 2/10
# 54000/54000 [==============================] - 1s 22us/step - loss: 0.0069 - acc: 0.9547 - val_loss: 0.0053 - val_acc: 0.9642
#
# Epoch 00002: val_loss improved from 0.00539 to 0.00532, saving model to drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model1/loss02-0.0053.hdf5
# Epoch 3/10
# 54000/54000 [==============================] - 1s 23us/step - loss: 0.0044 - acc: 0.9714 - val_loss: 0.0038 - val_acc: 0.9742
#
# Epoch 00003: val_loss improved from 0.00532 to 0.00383, saving model to drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model1/loss03-0.0038.hdf5
# Epoch 4/10
# ...

# %%
start_time = time.time() 
result8 = network8.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint8])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
start_time = time.time() 
result9 = network9.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint9])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
#start_time = time.time() 
#result10 = network10.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint10])
#print("start_time", start_time)
#print("--- %s seconds ---" %(time.time() - start_time))
start_time = time.time() 
result11 = network11.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint11])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
start_time = time.time() 
result12 = network12.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1, callbacks = [cb_checkpoint12])
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))

result13 = network13.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
result14 = network14.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 3s 50us/step - loss: 0.0097 - acc: 0.8467 - val_loss: 0.0035 - val_acc: 0.9488
#
# Epoch 00001: val_loss improved from inf to 0.00352, saving model to drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model8/loss01-0.0035.hdf5
# Epoch 2/10
# 54000/54000 [==============================] - 1s 22us/step - loss: 0.0031 - acc: 0.9561 - val_loss: 0.0018 - val_acc: 0.9730
#
# Epoch 00002: val_loss improved from 0.00352 to 0.00181, saving model to drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model8/loss02-0.0018.hdf5
# Epoch 3/10
# 54000/54000 [==============================] - 1s 23us/step - loss: 0.0021 - acc: 0.9701 - val_loss: 0.0019 - val_acc: 0.9723
#
# Epoch 00003: val_loss did not improve from 0.00181
# Epoch 4/10
# ...

# %%
start_time = time.time() 
result13 = network13.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))

start_time = time.time() 
result14 = network14.fit(train_images, train_labels, epochs= 10, batch_size=512, validation_split = 0.1)
print("start_time", start_time)
print("--- %s seconds ---" %(time.time() - start_time))
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 3s 50us/step - loss: 0.1421 - acc: 0.8642 - val_loss: 0.1119 - val_acc: 0.9638
# Epoch 2/10
# 54000/54000 [==============================] - 1s 21us/step - loss: 0.1136 - acc: 0.9579 - val_loss: 0.1119 - val_acc: 0.9628
# Epoch 3/10
# 54000/54000 [==============================] - 1s 21us/step - loss: 0.1083 - acc: 0.9740 - val_loss: 0.1104 - val_acc: 0.9690
# Epoch 4/10
# 54000/54000 [==============================] - 1s 21us/step - loss: 0.1056 - acc: 0.9828 - val_loss: 0.1066 - val_acc: 0.9802
# Epoch 5/10
# 54000/54000 [==============================] - 1s 21us/step - loss: 0.1042 - acc: 0.9865 - val_loss: 0.1075 - val_acc: 0.9790
# Epoch 6/10
# 54000/54000 [==============================] - 1s 21us/step - loss: 0.1031 - acc: 0.9899 - val_loss: 0.1104 - val_acc: 0.9763
# Epoch 7/10
# ...

# %%
n1_test_loss, n1_test_acc = network1.evaluate(test_images, test_labels)
print('n1_test_acc:', n1_test_acc)
print('n1_test_loss:', n1_test_loss)

n2_test_loss, n2_test_acc = network2.evaluate(test_images, test_labels)
print('n2_test_acc:', n2_test_acc)
print('n2_test_loss:', n2_test_loss)

n3_test_loss, n3_test_acc = network3.evaluate(test_images, test_labels)
print('n3_test_acc:', n3_test_acc)
print('n3_test_loss:', n3_test_loss)

n4_test_loss, n4_test_acc = network4.evaluate(test_images, test_labels)
print('n4_test_acc:', n4_test_acc)
print('n4_test_loss:', n4_test_loss)

n5_test_loss, n5_test_acc = network5.evaluate(test_images, test_labels)
print('n5_test_acc:', n5_test_acc)
print('n5_test_loss:', n5_test_loss)

n6_test_loss, n6_test_acc = network6.evaluate(test_images, test_labels)
print('n6_test_acc:', n6_test_acc)
print('n6_test_loss:', n6_test_loss)

n7_test_loss, n7_test_acc = network7.evaluate(test_images, test_labels)
print('n7_test_acc:', n7_test_acc)
print('n7_test_loss:', n7_test_loss)
# Out:
# 10000/10000 [==============================] - 1s 73us/step
# n1_test_acc: 0.9795
# n1_test_loss: 0.00334415732756715
# 10000/10000 [==============================] - 1s 73us/step
# n2_test_acc: 0.9687
# n2_test_loss: 0.006225115544412771
# 10000/10000 [==============================] - 1s 76us/step
# n3_test_acc: 0.9569
# n3_test_loss: 4303735.5179499565
# 10000/10000 [==============================] - 1s 79us/step
# n4_test_acc: 0.9789
# n4_test_loss: 0.0017055247430512721
# 10000/10000 [==============================] - 1s 84us/step
# n5_test_acc: 0.97
# n5_test_loss: 0.9026814491271973
# 10000/10000 [==============================] - 1s 84us/step
# n6_test_acc: 0.9717
# n6_test_loss: 0.9028264497756958
# 10000/10000 [==============================] - 1s 88us/step
# n7_test_acc: 0.9691
# n7_test_loss: 0.06015352650284767

# %%
n8_test_loss, n8_test_acc = network8.evaluate(test_images, test_labels)
print('n8_test_acc:', n8_test_acc)
print('n8_test_loss:', n8_test_loss)

n9_test_loss, n9_test_acc = network9.evaluate(test_images, test_labels)
print('n9_test_acc:', n9_test_acc)
print('n9_test_loss:', n9_test_loss)

#n10_test_loss, n10_test_acc = network10.evaluate(test_images, test_labels)
#print('n10_test_acc:', n10_test_acc)
#print('n10_test_loss:', n10_test_loss)

n11_test_loss, n11_test_acc = network11.evaluate(test_images, test_labels)
print('n11_test_acc:', n11_test_acc)
print('n11_test_loss:', n11_test_loss)

n12_test_loss, n12_test_acc = network12.evaluate(test_images, test_labels)
print('n12_test_acc:', n12_test_acc)
print('n12_test_loss:', n12_test_loss)

n13_test_loss, n13_test_acc = network13.evaluate(test_images, test_labels)
print('n13_test_acc:', n13_test_acc)
print('n13_test_loss:', n13_test_loss)

n14_test_loss, n14_test_acc = network14.evaluate(test_images, test_labels)
print('n14_test_acc:', n14_test_acc)
print('n14_test_loss:', n14_test_loss)
# Out:
# 10000/10000 [==============================] - 1s 81us/step
# n8_test_acc: 0.9766
# n8_test_loss: 0.0016498839267880762
# 10000/10000 [==============================] - 1s 80us/step
# n9_test_acc: 0.9801
# n9_test_loss: 0.10094519708142356
# 10000/10000 [==============================] - 1s 86us/step
# n11_test_acc: 0.9960799982070923
# n11_test_loss: 0.01757015826918373
# 10000/10000 [==============================] - 1s 90us/step
# n12_test_acc: 0.9783
# n12_test_loss: 0.10221200461661144
# 10000/10000 [==============================] - 1s 91us/step
# n13_test_acc: 0.9803
# n13_test_loss: 0.1092859718799591
# 10000/10000 [==============================] - 1s 91us/step
# n14_test_acc: 0.9788
# n14_test_loss: -0.9811065627098083

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def flotResult(data1,data2,data3,data4,data5):
    plt.figure(figsize=(5,5))
   


    plt.plot(data1,'r', label='Depth_1')
    plt.plot(data2,'g', label='Depth_3')
    plt.plot(data3,'b', label='Depth_5')
    plt.plot(data4,'c', label='Depth_7')
    plt.plot(data5,'m', label='Depth_19')
    
    plt.legend(loc='upper right')
    plt.show()

# %%
def flotResult2(title,data1,data2):
    plt.figure(figsize=(5,5))
    plt.title(title)
    plt.plot(data1,'r', label='train_loss')
    plt.plot(data2,'g', label='valid_loss')
    
    plt.legend(loc='upper right')
    plt.show()

# %%
flotResult2('mean_squared_error', result1.history['loss'], result1.history['val_loss'])
flotResult2('mean_absolute_error', result2.history['loss'], result2.history['val_loss'])
flotResult2('mean_absolute_percentage_error', result3.history['loss'], result3.history['val_loss'])
flotResult2('mean_squared_logarithmic_error', result4.history['loss'], result4.history['val_loss'])
flotResult2('squared_hinge', result5.history['loss'], result5.history['val_loss'])
flotResult2('hinge', result6.history['loss'], result6.history['val_loss'])
flotResult2('categorical_hinge', result7.history['loss'], result7.history['val_loss'])

# %%
flotResult2('logcosh', result8.history['loss'], result8.history['val_loss'])
flotResult2('categorical_crossentropy', result9.history['loss'], result9.history['val_loss'])
#flotResult2('sparse_categorical_crossentropy', result10.history['loss'], result9.history['val_loss'])
flotResult2('binary_crossentropy', result11.history['loss'], result11.history['val_loss'])
flotResult2('kullback_leibler_divergence', result12.history['loss'], result12.history['val_loss'])
flotResult2('poisson', result13.history['loss'], result13.history['val_loss'])
flotResult2('cosine_proximity', result14.history['loss'], result14.history['val_loss'])

# %%
flotResult(result1.history['loss'], result2.history['loss'],result3.history['loss'],result4.history['loss'],result5.history['loss'])
flotResult(result1.history['val_loss'], result2.history['val_loss'],result3.history['val_loss'],result4.history['val_loss'],result5.history['val_loss'])
flotResult(result1.history['acc'], result2.history['acc'],result3.history['acc'],result4.history['acc'],result5.history['acc'])
flotResult(result1.history['val_acc'], result2.history['val_acc'],result3.history['val_acc'],result4.history['val_acc'],result5.history['val_acc'])

# %%
test1 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model1/width07-0.0963.hdf5')
test2 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model2/width10-0.0728.hdf5')
test3 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model3/width07-0.0708.hdf5')
test4 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model4/width05-0.0732.hdf5')
test5 = load_model('drive/colab/BigData/BigdataProcessingProject/Assignment1/checkpoint/model5/width04-0.0678.hdf5')

# %%
n1_test_loss, n1_test_acc = test1.evaluate(test_images, test_labels)
print('n1_test_acc:', n1_test_acc)
print('n1_test_loss:', n1_test_loss)

n2_test_loss, n2_test_acc = test2.evaluate(test_images, test_labels)
print('n2_test_acc:', n2_test_acc)
print('n2_test_loss:', n2_test_loss)

n3_test_loss, n3_test_acc = test3.evaluate(test_images, test_labels)
print('n3_test_acc:', n3_test_acc)
print('n3_test_loss:', n3_test_loss)

n4_test_loss, n4_test_acc = test4.evaluate(test_images, test_labels)
print('n4_test_acc:', n4_test_acc)
print('n4_test_loss:', n4_test_loss)

n5_test_loss, n5_test_acc = test5.evaluate(test_images, test_labels)
print('n5_test_acc:', n5_test_acc)
print('n5_test_loss:', n5_test_loss)
# Out:
# 10000/10000 [==============================] - 1s 116us/step
# n1_test_acc: 0.9676
# n1_test_loss: 0.10624269597809761
# 10000/10000 [==============================] - 1s 116us/step
# n2_test_acc: 0.979
# n2_test_loss: 0.07169286415517563
# 10000/10000 [==============================] - 1s 118us/step
# n3_test_acc: 0.9787
# n3_test_loss: 0.07353732150335564
# 10000/10000 [==============================] - 1s 119us/step
# n4_test_acc: 0.9789
# n4_test_loss: 0.06913991090978962
# 10000/10000 [==============================] - 1s 128us/step
# n5_test_acc: 0.9794
# n5_test_loss: 0.0690032683753583

# %%
del network1
del network2
del network3
del network4
del network5
del network6
del network7

del result1
del result2
del result3
del result4
del result5
del result6
del result7

# %%
del network7
del network8
del network9
del network10
del network11
del network12

del result7
del result8
del result9
del result10
del result11
del result12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-a83a6b160334> in <module>()
# ----> 1 del network8
#       2 del network9
#       3 del network10
#       4 del network11
#       5 del network12
#
# NameError: name 'network8' is not defined

# %%
del network11
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-0cbb60881485> in <module>()
# ----> 1 del network11
#
# NameError: name 'network11' is not defined
